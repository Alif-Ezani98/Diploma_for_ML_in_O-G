# %% [markdown]
# # Pandas & Data Management
#
# - Extremely powerful version of MS Excel in python

# %%
import numpy as np
import pandas as pd

# %%
# Series: similar to numpy array, + index by a label
# index: address

### Human Name: Alif : array

### human array + label = series

# %%
poro1 = np.array([0.41,0.37,0.15])

# %%
poro1
# Out:
# array([0.41, 0.37, 0.15])

# %%
poro1[1]
# Out:
# 0.37

# %%
poro_series = pd.Series(data=poro1,index =["a","b","c"])

# %%
poro_series
# Out:
# a    0.41
# b    0.37
# c    0.15
# dtype: float64

# %%
type(poro_series)
# Out:
# pandas.core.series.Series

# %%
poro_series
# Out:
# a    0.41
# b    0.37
# c    0.15
# dtype: float64

# %%
depth = [2000,2500,3000]

# %%
depth_wise_poro_series = pd.Series(data=poro1,index=depth,name="Phi vs Depth")

# %%
depth_wise_poro_series
# Out:
# 2000    0.41
# 2500    0.37
# 3000    0.15
# Name: Phi vs Depth, dtype: float64

# %%
## in built pandas plotting

# %%
depth_wise_poro_series.plot()
# Out:
# <Axes: >

# %%
poro_series.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(poro1,depth)

# %%
#create a series using dictionary

# %%
perm = {"rockA":20,"rockB":30,"rockC":50}

# %%
perm
# Out:
# {'rockA': 20, 'rockB': 30, 'rockC': 50}

# %%
perm_series = pd.Series(perm)

# %%
perm_series
# Out:
# rockA    20
# rockB    30
# rockC    50
# dtype: int64

# %%
perm_series.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Pandas DataFrames
#
# dataframe: bunch of series objects put together to share the same index
#
# - Numpy array basic brick: data w/o some predefined index
#
# - Numpy array +label/index = Series
#
# - Multiple series + COmmon index = DataFrame
#
# - df = looks like a table/excel/csv

# %%
depth
# Out:
# [2000, 2500, 3000]

# %%
poro1
# Out:
# array([0.41, 0.37, 0.15])

# %%
perm = [23,34,43]

# %%
depth_wise_poro_series
# Out:
# 2000    0.41
# 2500    0.37
# 3000    0.15
# Name: Phi vs Depth, dtype: float64

# %%
depth_wise_perm_series = pd.Series(data=perm,index=depth,name="Perm vs Depth")

# %%
depth_wise_perm_series
# Out:
# 2000    23
# 2500    34
# 3000    43
# Name: Perm vs Depth, dtype: int64

# %%
pd.DataFrame([depth_wise_perm_series,depth_wise_poro_series]).T
# Out:
#       Perm vs Depth  Phi vs Depth
# 2000           23.0          0.41
# 2500           34.0          0.37
# 3000           43.0          0.15

# %%
my_field_data = {"Depth":depth,"Porosity":poro1,"Permeability":perm}

# %%
my_field_data
# Out:
# {'Depth': [2000, 2500, 3000],
#  'Porosity': array([0.41, 0.37, 0.15]),
#  'Permeability': [23, 34, 43]}

# %%
df = pd.DataFrame(my_field_data)

# %%
df
# Out:
#    Depth  Porosity  Permeability
# 0   2000      0.41            23
# 1   2500      0.37            34
# 2   3000      0.15            43

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df
# Out:
#    Depth  Porosity  Permeability
# 0   2000      0.41            23
# 1   2500      0.37            34
# 2   3000      0.15            43

# %%
df
# Out:
#    Depth  Porosity  Permeability
# 0   2000      0.41            23
# 1   2500      0.37            34
# 2   3000      0.15            43

# %%
df
# Out:
#    Depth  Porosity  Permeability
# 0   2000      0.41            23
# 1   2500      0.37            34
# 2   3000      0.15            43

# %%
#accesing a column
df["Porosity"]
# Out:
# 0    0.41
# 1    0.37
# 2    0.15
# Name: Porosity, dtype: float64

# %%
#setting index
df.index = df["Depth"]

# %%
df.index
# Out:
# Int64Index([2000, 2500, 3000], dtype='int64', name='Depth')

# %%
df
# Out:
#        Depth  Porosity  Permeability
# Depth
# 2000    2000      0.41            23
# 2500    2500      0.37            34
# 3000    3000      0.15            43

# %%
## dropping a column
df.drop("Depth",axis=1)
# Out:
#        Porosity  Permeability
# Depth
# 2000       0.41            23
# 2500       0.37            34
# 3000       0.15            43

# %%
df
# Out:
#        Depth  Porosity  Permeability
# Depth
# 2000    2000      0.41            23
# 2500    2500      0.37            34
# 3000    3000      0.15            43

# %%
df.drop("Depth",axis=1)
# Out:
#        Porosity  Permeability
# Depth
# 2000       0.41            23
# 2500       0.37            34
# 3000       0.15            43

# %%
df.drop(2500)
# Out:
#        Depth  Porosity  Permeability
# Depth
# 2000    2000      0.41            23
# 3000    3000      0.15            43

# %%
df
# Out:
#        Depth  Porosity  Permeability
# Depth
# 2000    2000      0.41            23
# 2500    2500      0.37            34
# 3000    3000      0.15            43

# %%
zones = ["zone_A","zone_B","zone_C"]

# %%
df
# Out:
#        Depth  Porosity  Permeability
# Depth
# 2000    2000      0.41            23
# 2500    2500      0.37            34
# 3000    3000      0.15            43

# %%
df.index
# Out:
# Int64Index([2000, 2500, 3000], dtype='int64', name='Depth')

# %%
df.index = zones

# %%
df
# Out:
#         Depth  Porosity  Permeability
# zone_A   2000      0.41            23
# zone_B   2500      0.37            34
# zone_C   3000      0.15            43

# %% [markdown]
# ### Accessing column/columns

# %%
df["Porosity"]
# Out:
# zone_A    0.41
# zone_B    0.37
# zone_C    0.15
# Name: Porosity, dtype: float64

# %%
type(df["Porosity"])
# Out:
# pandas.core.series.Series

# %%
#access more than 1 column

# %%
df[['Porosity',"Permeability"]]
# Out:
#         Porosity  Permeability
# zone_A      0.41            23
# zone_B      0.37            34
# zone_C      0.15            43

# %%
df[["Porosity"]]
# Out:
#         Porosity
# zone_A      0.41
# zone_B      0.37
# zone_C      0.15

# %% [markdown]
# ## Accessing rows
#
# - loc:labels
# - iloc: index number

# %%
df
# Out:
#         Depth  Porosity  Permeability
# zone_A   2000      0.41            23
# zone_B   2500      0.37            34
# zone_C   3000      0.15            43

# %%
df.loc["zone_B"]
# Out:
# Depth           2500.00
# Porosity           0.37
# Permeability      34.00
# Name: zone_B, dtype: float64

# %%
df.iloc[2] # index location
# Out:
# Depth           3000.00
# Porosity           0.15
# Permeability      43.00
# Name: zone_C, dtype: float64

# %%
df.loc[["zone_A","zone_C"]]
# Out:
#         Depth  Porosity  Permeability
# zone_A   2000      0.41            23
# zone_C   3000      0.15            43

# %%
df
# Out:
#         Depth  Porosity  Permeability
# zone_A   2000      0.41            23
# zone_B   2500      0.37            34
# zone_C   3000      0.15            43

# %%
df.iloc[::2]
# Out:
#         Depth  Porosity  Permeability
# zone_A   2000      0.41            23
# zone_C   3000      0.15            43

# %%
df
# Out:
#         Depth  Porosity  Permeability
# zone_A   2000      0.41            23
# zone_B   2500      0.37            34
# zone_C   3000      0.15            43

# %%
df[["Permeability"]]
# Out:
#         Permeability
# zone_A            23
# zone_B            34
# zone_C            43

# %%
df[["Permeability"]].loc[["zone_A","zone_C"]]
# Out:
#         Permeability
# zone_A            23
# zone_C            43

# %%
df
# Out:
#         Depth  Porosity  Permeability
# zone_A   2000      0.41            23
# zone_B   2500      0.37            34
# zone_C   3000      0.15            43

# %%
df.loc[["zone_A","zone_C"]][["Permeability"]]
# Out:
#         Permeability
# zone_A            23
# zone_C            43

# %% [markdown]
# ## dropping rows/colums

# %%
df
# Out:
#         Depth  Porosity  Permeability
# zone_A   2000      0.41            23
# zone_B   2500      0.37            34
# zone_C   3000      0.15            43

# %%
df.drop("zone_B")
# Out:
#         Depth  Porosity  Permeability
# zone_A   2000      0.41            23
# zone_C   3000      0.15            43

# %%
df
# Out:
#         Depth  Porosity  Permeability
# zone_A   2000      0.41            23
# zone_B   2500      0.37            34
# zone_C   3000      0.15            43

# %%
#dropping column, pass axis=1
df.drop("Depth",axis=1)
# Out:
#         Porosity  Permeability
# zone_A      0.41            23
# zone_B      0.37            34
# zone_C      0.15            43

# %% [markdown]
# ## Adding Column

# %%
df
# Out:
#         Depth  Porosity  Permeability
# zone_A   2000      0.41            23
# zone_B   2500      0.37            34
# zone_C   3000      0.15            43

# %%
df["Lithology"] = ["Limestone","Sandstone","Shale"]

# %%
df
# Out:
#         Depth  Porosity  Permeability  Lithology
# zone_A   2000      0.41            23  Limestone
# zone_B   2500      0.37            34  Sandstone
# zone_C   3000      0.15            43      Shale

# %%
df["Por_Perm_Product"] = df['Permeability']*df["Porosity"]

# %%
df
# Out:
#         Depth  Porosity  Permeability  Lithology  PorPermProduct   Temp  \
# zone_A   2000      0.41            23  Limestone            9.43  185.0
# zone_B   2500      0.37            34  Sandstone           12.58  225.0
# zone_C   3000      0.15            43      Shale            6.45  265.0
#
#         Por_Perm_Product
# zone_A              9.43
# zone_B             12.58
# zone_C              6.45

# %%
geothermal_grad = 0.08 #degree celsius/feet
surface_temp = 25

df["Temp"] = surface_temp + geothermal_grad*df["Depth"]

# %%
df
# Out:
#         Depth  Porosity  Permeability  Lithology  PorPermProduct   Temp  \
# zone_A   2000      0.41            23  Limestone            9.43  185.0
# zone_B   2500      0.37            34  Sandstone           12.58  225.0
# zone_C   3000      0.15            43      Shale            6.45  265.0
#
#         Por_Perm_Product
# zone_A              9.43
# zone_B             12.58
# zone_C              6.45

# %% [markdown]
# ## some info

# %%
df
# Out:
#         Depth  Porosity  Permeability  Lithology  PorPermProduct   Temp  \
# zone_A   2000      0.41            23  Limestone            9.43  185.0
# zone_B   2500      0.37            34  Sandstone           12.58  225.0
# zone_C   3000      0.15            43      Shale            6.45  265.0
#
#         Por_Perm_Product
# zone_A              9.43
# zone_B             12.58
# zone_C              6.45

# %%
len(df)
# Out:
# 3

# %%
df.shape
# Out:
# (3, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, zone_A to zone_C
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Depth             3 non-null      int64
#  1   Porosity          3 non-null      float64
#  2   Permeability      3 non-null      int64
#  3   Lithology         3 non-null      object
#  4   PorPermProduct    3 non-null      float64
#  5   Temp              3 non-null      float64
#  6   Por_Perm_Product  3 non-null      float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 300.0+ bytes

# %%
df.describe()
# Out:
#         Depth  Porosity  Permeability  PorPermProduct   Temp  Por_Perm_Product
# count     3.0      3.00      3.000000        3.000000    3.0          3.000000
# mean   2500.0      0.31     33.333333        9.486667  225.0          9.486667
# std     500.0      0.14     10.016653        3.065393   40.0          3.065393
# min    2000.0      0.15     23.000000        6.450000  185.0          6.450000
# 25%    2250.0      0.26     28.500000        7.940000  205.0          7.940000
# 50%    2500.0      0.37     34.000000        9.430000  225.0          9.430000
# 75%    2750.0      0.39     38.500000       11.005000  245.0         11.005000
# max    3000.0      0.41     43.000000       12.580000  265.0         12.580000

# %% [markdown]
# ## Conditional Dataframe

# %%
df
# Out:
#         Depth  Porosity  Permeability  Lithology  PorPermProduct   Temp  \
# zone_A   2000      0.41            23  Limestone            9.43  185.0
# zone_B   2500      0.37            34  Sandstone           12.58  225.0
# zone_C   3000      0.15            43      Shale            6.45  265.0
#
#         Por_Perm_Product
# zone_A              9.43
# zone_B             12.58
# zone_C              6.45

# %%
#depth > 1200

# %%
df["Depth"] > 1200
# Out:
# zone_A    True
# zone_B    True
# zone_C    True
# Name: Depth, dtype: bool

# %%
df[df["Depth"] > 1200]
# Out:
#         Depth  Porosity  Permeability  Lithology  PorPermProduct   Temp  \
# zone_A   2000      0.41            23  Limestone            9.43  185.0
# zone_B   2500      0.37            34  Sandstone           12.58  225.0
# zone_C   3000      0.15            43      Shale            6.45  265.0
#
#         Por_Perm_Product
# zone_A              9.43
# zone_B             12.58
# zone_C              6.45

# %%
df
# Out:
#         Depth  Porosity  Permeability  Lithology  PorPermProduct   Temp  \
# zone_A   2000      0.41            23  Limestone            9.43  185.0
# zone_B   2500      0.37            34  Sandstone           12.58  225.0
# zone_C   3000      0.15            43      Shale            6.45  265.0
#
#         Por_Perm_Product
# zone_A              9.43
# zone_B             12.58
# zone_C              6.45

# %%
#porosity is less than 0.3

# %%
df["Porosity"] < 0.3
# Out:
# zone_A    False
# zone_B    False
# zone_C     True
# Name: Porosity, dtype: bool

# %%
df[df["Porosity"] < 0.3]
# Out:
#         Depth  Porosity  Permeability Lithology  PorPermProduct   Temp  \
# zone_C   3000      0.15            43     Shale            6.45  265.0
#
#         Por_Perm_Product
# zone_C              6.45

# %%
df
# Out:
#         Depth  Porosity  Permeability  Lithology  PorPermProduct   Temp  \
# zone_A   2000      0.41            23  Limestone            9.43  185.0
# zone_B   2500      0.37            34  Sandstone           12.58  225.0
# zone_C   3000      0.15            43      Shale            6.45  265.0
#
#         Por_Perm_Product
# zone_A              9.43
# zone_B             12.58
# zone_C              6.45

# %%
df[df["Lithology"]=="Shale"]
# Out:
#         Depth  Porosity  Permeability Lithology  PorPermProduct   Temp  \
# zone_C   3000      0.15            43     Shale            6.45  265.0
#
#         Por_Perm_Product
# zone_C              6.45

# %% [markdown]
# # I/O

# %%
df
# Out:
#         Depth  Porosity  Permeability  Lithology  PorPermProduct   Temp  \
# zone_A   2000      0.41            23  Limestone            9.43  185.0
# zone_B   2500      0.37            34  Sandstone           12.58  225.0
# zone_C   3000      0.15            43      Shale            6.45  265.0
#
#         Por_Perm_Product
# zone_A              9.43
# zone_B             12.58
# zone_C              6.45

# %%
df.to_csv(r"C:/Users/alif.haiqal/Documents/Dip_ML_for_O-G/Day 08 - 10/Reservoir Data.csv")

# %%
a = pd.read_csv(r"C:\Users\alif.haiqal\Documents\Dip_ML_for_O-G\Day 08 - 10\Reservoir Data.csv")

# %%
a
# Out:
#   Unnamed: 0  Depth  Porosity  Permeability  Lithology  PorPermProduct   Temp  \
# 0     zone_A   2000      0.41            23  Limestone            9.43  185.0
# 1     zone_B   2500      0.37            34  Sandstone           12.58  225.0
# 2     zone_C   3000      0.15            43      Shale            6.45  265.0
#
#    Por_Perm_Product
# 0              9.43
# 1             12.58
# 2              6.45

# %% [markdown]
# ## Assignment 2: Write a code, where porosity and perm thresholds will be given by user and you will return final dataframe.

# %%
poro_thresh = float(input("What is the porosity threshold? : "))
perm_thresh = float(input("What is the permeability threshold? : "))
print()

print(f"The zone(s) with porosity < {poro_thresh} and permeability < {perm_thresh} is/are as following:")

df[(df["Porosity"] < poro_thresh) & (df["Permeability"] < perm_thresh)]
# Out:
# What is the porosity threshold? : 0.4
# What is the permeability threshold? : 50
#
# The zone(s) with porosity < 0.4 and permeability < 50.0 is/are as following:
#         Depth  Porosity  Permeability  Lithology  PorPermProduct   Temp  \
# zone_B   2500      0.37            34  Sandstone           12.58  225.0
# zone_C   3000      0.15            43      Shale            6.45  265.0
#
#         Por_Perm_Product
# zone_B             12.58
# zone_C              6.45
